# %% [markdown]
# <a href="https://colab.research.google.com/github/RachitBansal/Power-Forecasting/blob/master/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
import os

# %%
items = os.listdir("My Drive/Greend")

# %%
src_path = "My Drive/Greend/"
dest_path = "My Drive/Greend/LSTM_results/extra/"

# %%
from sklearn.externals import joblib
from keras.layers import Dense ,LSTM
from keras.models import Sequential 
from sklearn.metrics import mean_absolute_error,mean_squared_error
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import pyplot
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Flatten
from sklearn.metrics import r2_score as r2Conversations
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
import os
import argparse
from keras.models import load_model
from keras.callbacks import EarlyStopping,ModelCheckpoint

        #parser = argparse.ArgumentParser(description="Run LSTM")
        #parser.add_argument('--num_equips', type='int')
        #parser.add_argument('--train', type='bool')
        #parser.add_argument('--src_dir')
        #parser.add_argument('--tgt_dir')
        #parser.add_argument('--n_test', type='int')
        #parser.add_argument('--n_models', type = 'int')
        #args = parser.parse_args()
        #run_LSTM(args.num_equips, args.n_test, args.n_models, args.src_dir, args.tgt_dir, args.train)

# %%
earlystop = EarlyStopping(monitor = "val_loss",patience = 5,restore_best_weights=True,mode = "auto")

# %%
class LSTM_pipeline:
    def __init__(self,equipment,n_members,src_path,trg_path):
        self.eq = equipment
        self.n_members = int(n_members)
        self.s_path = src_path
        self.t_path = trg_path
        
    def fit_lstm(self,x_train,y_train):
        regressor = Sequential()
        regressor.add(LSTM(units = 8,activation = "relu",input_shape= (128,1)))
        regressor.add(Dense(units = 1))
        regressor.compile(optimizer = "adam",loss = "mean_squared_error",metrics =["accuracy"])
        regressor.fit(x_train,y_train,epochs =10,batch_size = 128,validation_split = 0.1,callbacks = [earlystop])
        return regressor

    def load_data(self):
        self.train_x = np.load(file=self.s_path+'x_greend_eq'+str(self.eq-1)+'.npy')/300
        self.train_y = np.load(file=self.s_path+'y_greend_eq'+str(self.eq-1)+'.npy')/300
        test_x = np.load(file=self.s_path+'xt_greend_eq'+str(self.eq-1)+'.npy')/300
        test_y = np.load(file=self.s_path+'yt_greend_eq'+str(self.eq-1)+'.npy')/300
        val_split = int(0.2*test_x.shape[0])
        self.train_x = self.train_x.reshape(-1,128,1)
        self.train_y  = self.train_y.reshape(-1,1)
        self.val_x = test_x[-val_split:].reshape(-1,128,1)
        self.val_y = test_y[-val_split:].reshape(-1,1)
        self.test_x = test_x[:-val_split].reshape(-1,128,1)
        self.test_y = test_y[:-val_split].reshape(-1,1)
        print(self.val_x.shape, self.val_y.shape, self.test_x.shape, self.test_y.shape)
        
    def load_all_models(self):
        all_models = list()
        for i in range(self.n_members):
            filename = self.t_path + str(self.eq-1) + '_model_' + str(i + 1) + '.h5'
            model = load_model(filename)
            all_models.append(model)
            print('>>> loaded %s' % filename)
        return all_models
        
    def metricss(self, n_test):
        preds = self.preds
        test_y = self.test_y[:n_test].reshape(-1)
        error = mean_squared_error(test_y, preds)
        print('Test MSE: %.3f' % error)
        print("RMSE : %.3f"%(np.sqrt(error)))
        print("MAE : %.3f"%(mean_absolute_error(test_y,preds)))
      
    def predictions(self, n_test, idx=0):
        self.preds = None     
        predicted = None
        temp_x = self.test_x[:n_test]
        temp_x = temp_x.reshape(-1,128,1)
        predicted =  self.members[0].predict(temp_x)
        predicted = predicted
        self.preds = predicted.reshape(-1)
        self.metricss(n_test)

    def make_lstm_comparison_graph(self, n_test, idx=0):
        self.predictions(n_test, idx)
        temp1 = self.test_y[idx:idx+n_test].reshape(-1)
        plt.plot(temp1, c = 'yellow', label='actual')
        plt.plot(self.preds, c = 'red', label='LSTM')
        plt.ylabel('Value')
        plt.xlabel('Index of Time Series Data')
        plt.legend()
        plt.savefig(self.t_path + str(self.eq-1) + '_graph_' + '.png')
        plt.show()

    def pipeline(self, n_test, train=True):
        self.load_data()
        if(train):
            for i in range(self.n_members):
                print(self.train_x.shape)
                model = self.fit_lstm(self.train_x, self.train_y)
                filename = self.t_path + str(self.eq-1) + '_model_' + str(i + 1) + '.h5'
                model.save(filename)
                print('>>> Saved %s' % filename)

        self.members = self.load_all_models()
        print('Loaded %d models' % len(self.members))
        idx = 0
        self.make_lstm_comparison_graph(n_test, idx) 
        
     
''' hello world'''
def run_LSTM(num_equips, n_test, n_models, src_dir, tgt_dir, train = True):
    d = {}
    for i in range(num_equips):
        d["obj{0}".format(i)] = LSTM_pipeline(i+1, n_models, src_dir, tgt_dir)
        d["obj{0}".format(i)].pipeline(n_test, train)
    
run_LSTM(9, 100, 1, src_path,dest_path, False)
# Out:
# (8612, 128, 1) (8612, 1) (34452, 128, 1) (34452, 1)
# (100481, 128, 1)
# Train on 90432 samples, validate on 10049 samples
# Epoch 1/10
# 90432/90432 [==============================] - 71s 789us/step - loss: 38053.1469 - acc: 0.1179 - val_loss: 39329.9602 - val_acc: 0.0000e+00
# Epoch 2/10
# 90432/90432 [==============================] - 57s 631us/step - loss: 37891.2605 - acc: 1.1058e-04 - val_loss: 38339.8168 - val_acc: 0.0000e+00
# Epoch 3/10
# 90432/90432 [==============================] - 57s 631us/step - loss: 37308.7226 - acc: 0.0000e+00 - val_loss: 37831.7559 - val_acc: 0.0000e+00
# Epoch 4/10
# 90432/90432 [==============================] - 56s 623us/step - loss: 36609.7397 - acc: 0.0000e+00 - val_loss: 36977.9429 - val_acc: 0.0000e+00
# Epoch 5/10
# 90432/90432 [==============================] - 56s 624us/step - loss: 4383135.3449 - acc: 5.8608e-04 - val_loss: 30898.4502 - val_acc: 9.9512e-05
# Epoch 6/10
# 90432/90432 [==============================] - 56s 623us/step - loss: 29505.7076 - acc: 0.0000e+00 - val_loss: 30429.0173 - val_acc: 0.0000e+00
# Epoch 7/10
# 90432/90432 [==============================] - 56s 622us/step - loss: 29234.7301 - acc: 3.3174e-05 - val_loss: 30064.7417 - val_acc: 0.0000e+00
# Epoch 8/10
# 90432/90432 [==============================] - 57s 629us/step - loss: 29020.0083 - acc: 3.3174e-05 - val_loss: 30048.8636 - val_acc: 9.9512e-05
# Epoch 9/10
# 90432/90432 [==============================] - 57s 630us/step - loss: 29023.2806 - acc: 1.1058e-04 - val_loss: 29640.9878 - val_acc: 9.9512e-05
# Epoch 10/10
# 90432/90432 [==============================] - 57s 633us/step - loss: 28496.3757 - acc: 1.6587e-04 - val_loss: 28921.5048 - val_acc: 0.0000e+00
# >>> Saved My Drive/Greend/LSTM_results/extra/0_model_1.h5
# >>> loaded My Drive/Greend/LSTM_results/extra/0_model_1.h5
# Loaded 1 models
# Test MSE: 28243.343
# RMSE : 168.058
# MAE : 107.339
# (8612, 128, 1) (8612, 1) (34452, 128, 1) (34452, 1)
# (100481, 128, 1)
# Train on 90432 samples, validate on 10049 samples
# Epoch 1/10
# 90432/90432 [==============================] - 73s 808us/step - loss: 2792.7428 - acc: 0.0029 - val_loss: 352.3759 - val_acc: 0.0000e+00
# Epoch 2/10
# 90432/90432 [==============================] - 58s 637us/step - loss: 93.2035 - acc: 1.1058e-05 - val_loss: 38.3537 - val_acc: 0.0000e+00
# Epoch 3/10
# 90432/90432 [==============================] - 58s 636us/step - loss: 27.2784 - acc: 1.1058e-05 - val_loss: 23.5005 - val_acc: 0.0000e+00
# Epoch 4/10
# 90432/90432 [==============================] -
# 90432/90432 [==============================] - 56s 621us/step - loss: 1018.8198 - acc: 0.0000e+00 - val_loss: 1028.4130 - val_acc: 0.0000e+00
# Epoch 6/10
# 90432/90432 [==============================] - 57s 633us/step - loss: 1018.4218 - acc: 0.0000e+00 - val_loss: 1028.3314 - val_acc: 0.0000e+00
# Epoch 7/10
# 90432/90432 [==============================] - 57s 630us/step - loss: 1018.2578 - acc: 0.0000e+00 - val_loss: 1027.9014 - val_acc: 0.0000e+00
# Epoch 8/10
# 90432/90432 [==============================] - 57s 635us/step - loss: 1017.7613 - acc: 0.0000e+00 - val_loss: 1027.3794 - val_acc: 0.0000e+00
# Epoch 9/10
# 90432/90432 [==============================] - 57s 633us/step - loss: 1017.1461 - acc: 0.0000e+00 - val_loss: 1026.7185 - val_acc: 0.0000e+00
# Epoch 10/10
# 90432/90432 [==============================] - 57s 627us/step - loss: 1016.6335 - acc: 0.0000e+00 - val_loss: 1025.9144 - val_acc: 0.0000e+00
# >>> Saved My Drive/Greend/LSTM_results/extra/7_model_1.h5
# >>> loaded My Drive/Greend/LSTM_results/extra/7_model_1.h5
# Loaded 1 models
# Test MSE: 431.255
# RMSE : 20.767
# MAE : 6.070
# (8612, 128, 1) (8612, 1) (34452, 128, 1) (34452, 1)
# (100481, 128, 1)
# Train on 90432 samples, validate on 10049 samples
# Epoch 1/10
# 90432/90432 [==============================] - 76s 839us/step - loss: 1.4608 - acc: 0.9870 - val_loss: 3.6698 - val_acc: 0.9867
# Epoch 2/10
# 90432/90432 [==============================] - 57s 626us/step - loss: 752.6268 - acc: 0.9874 - val_loss: 3.6684 - val_acc: 0.9866
# Epoch 3/10
# 90432/90432 [==============================] - 57s 632us/step - loss: 1.4575 - acc: 0.9875 - val_loss: 3.6676 - val_acc: 0.9866
# Epoch 4/10
# 90432/90432 [==============================] - 56s 622us/step - loss: 1.4573 - acc: 0.9875 - val_loss: 3.6670 - val_acc: 0.9867
# Epoch 5/10
# 90432/90432 [==============================] - 56s 623us/step - loss: 1.4572 - acc: 0.9875 - val_loss: 3.6668 - val_acc: 0.9868
# Epoch 6/10
# 90432/90432 [==============================] - 57s 630us/step - loss: 1.4571 - acc: 0.9876 - val_loss: 3.6665 - val_acc: 0.9868
# Epoch 7/10
# 90432/90432 [==============================] - 56s 624us/step - loss: 1.4571 - acc: 0.9877 - val_loss: 3.6662 - val_acc: 0.9868
# Epoch 8/10
# 90432/90432 [==============================] - 57s 625us/step - loss: 1.4571 - acc: 0.9877 - val_loss: 3.6665 - val_acc: 0.9869
# Epoch 9/10
# 90432/90432 [==============================] - 56s 624us/step - loss: 1.4571 - acc: 0.9877 - val_loss: 3.6664 - val_acc: 0.9869
# Epoch 10/10
# 90432/90432 [==============================] - 56s 620us/step - loss: 1.4570 - acc: 0.9877 - val_loss: 3.6662 - val_acc: 0.9869
# >>> Saved My Drive/Greend/LSTM_results/extra/8_model_1.h5
# >>> loaded My Drive/Greend/LSTM_results/extra/8_model_1.h5
# Loaded 1 models
# Test MSE: 6.968
# RMSE : 2.640
# MAE : 0.430
